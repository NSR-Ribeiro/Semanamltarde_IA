# %%
pip install python-docx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from docx import Document

# %%
pip install reportlab
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib python-docx reportlab
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from docx import Document
import matplotlib.pyplot as plt

# Função para criar um relatório
def criar_relatorio(dados):
    # Criar um documento Word
    doc = Document()
    doc.add_heading('Relatório de Laudo de Engenharia Civil', level=1)

    # Adicionar dados
    doc.add_heading('Dados Coletados', level=2)
    for key, value in dados.items():
        doc.add_paragraph(f"{key}: {value}")

    # Adicionar gráfico (exemplo simples)
    plt.figure(figsize=(10, 5))
    plt.bar(dados['Categorias'], dados['Valores'], color='blue')
    plt.title('Distribuição de Valores por Categoria')
    plt.xlabel('Categorias')
    plt.ylabel('Valores')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig('grafico.png')
    plt.close()

    doc.add_heading('Gráfico de Distribuição', level=2)
    doc.add_picture('grafico.png')

    # Salvar o documento
    doc.save('relatorio_laudo_engenharia.docx')
    print("Relatório gerado com sucesso!")

# Exemplo de dados
dados = {
    'Data da Inspeção': '2024-10-29',
    'Engenheiro Responsável': 'Eng. Natanael Ribeiro',
    'Categorias': ['Estruturas', 'Fundação', 'Acabamentos'],
    'Valores': [100, 70, 90],
    'Observações': 'Tudo dentro dos padrões exigidos.'
}

# Chamar a função
criar_relatorio(dados)
# Out:
# Relatório gerado com sucesso!

# %%
import matplotlib.pyplot as plt
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib import utils

# Função para criar um gráfico
def criar_grafico(categorias, valores):
    plt.figure(figsize=(10, 5))
    plt.bar(categorias, valores, color='blue')
    plt.title('Distribuição de Valores por Categoria')
    plt.xlabel('Categorias')
    plt.ylabel('Valores')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig('grafico.png')
    plt.close()

# Função para adicionar uma imagem ao PDF
def adicionar_imagem(pdf, img_path, x, y, width, height):
    pdf.drawImage(img_path, x, y, width, height, preserveAspectRatio=True)

# Função para criar um relatório em PDF
def criar_relatorio_pdf(dados):
    # Validação dos dados
    if len(dados['Categorias']) != len(dados['Valores']):
        raise ValueError("O número de categorias deve ser igual ao número de valores.")

    # Criar gráfico
    criar_grafico(dados['Categorias'], dados['Valores'])

    # Criar PDF
    pdf = canvas.Canvas("relatorio_laudo_engenharia.pdf", pagesize=letter)
    pdf.setTitle("Relatório de Laudo de Engenharia Civil")
    
    # Adicionar título
    pdf.setFont("Helvetica-Bold", 24)
    pdf.drawString(100, 750, "Relatório de Laudo de Engenharia Civil")
    
    # Adicionar dados
    pdf.setFont("Helvetica-Bold", 18)
    pdf.drawString(100, 700, "Dados Coletados:")
    
    pdf.setFont("Helvetica", 12)
    y = 670
    for key, value in dados.items():
        if key not in ['Categorias', 'Valores']:  # Evitar adicionar listas
            pdf.drawString(100, y, f"{key}: {value}")
            y -= 20

    # Adicionar gráfico
    pdf.setFont("Helvetica-Bold", 18)
    pdf.drawString(100, y, "Gráfico de Distribuição:")
    y -= 20

    adicionar_imagem(pdf, 'grafico.png', 100, y, 400, 200)

    # Salvar o documento
    pdf.save()
    print("Relatório gerado com sucesso!")

# Exemplo de dados
dados = {
    'Data da Inspeção': '2024-10-29',
    'Engenheiro Responsável': 'Eng. Natanael Ribeiro',
    'Categorias': ['Estruturas', 'Fundação', 'Acabamentos'],
    'Valores': [100, 70, 90],
    'Observações': 'Tudo dentro dos padrões exigidos.'
}

# Gerar o relatório
criar_relatorio_pdf(dados)
# Out:
# Relatório gerado com sucesso!

# %%
import matplotlib.pyplot as plt
from docx import Document
from docx.shared import Inches
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas

# Função para criar um gráfico
def criar_grafico(categorias, valores):
    plt.figure(figsize=(10, 5))
    plt.bar(categorias, valores, color='blue')
    plt.title('Distribuição de Valores por Categoria')
    plt.xlabel('Categorias')
    plt.ylabel('Valores')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig('grafico.png')
    plt.close()

# Função para adicionar uma imagem ao PDF
def adicionar_imagem(pdf, img_path, x, y, width, height):
    pdf.drawImage(img_path, x, y, width, height, preserveAspectRatio=True)

# Função para criar um relatório em PDF
def criar_relatorio_pdf(dados):
    if len(dados['Categorias']) != len(dados['Valores']):
        raise ValueError("O número de categorias deve ser igual ao número de valores.")

    # Criar gráfico
    criar_grafico(dados['Categorias'], dados['Valores'])

    # Cri

# %%
import matplotlib.pyplot as plt
from docx import Document
from docx.shared import Inches
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas

# Função para criar um gráfico
def criar_grafico(categorias, valores):
    plt.figure(figsize=(10, 5))
    plt.bar(categorias, valores, color='blue')
    plt.title('Distribuição de Valores por Categoria')
    plt.xlabel('Categorias')
    plt.ylabel('Valores')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig('grafico.png')
    plt.close()

# Função para adicionar uma imagem ao PDF
def adicionar_imagem(pdf, img_path, x, y, width, height):
    pdf.drawImage(img_path, x, y, width, height, preserveAspectRatio=True)

# Função para criar um relatório em PDF
def criar_relatorio_pdf(dados):
    if len(dados['Categorias']) != len(dados['Valores']):
        raise ValueError("O número de categorias deve ser igual ao número de valores.")

    # Criar gráfico
    criar_grafico(dados['Categorias'], dados['Valores'])

    # Criar PDF
    pdf = canvas.Canvas("relatorio_laudo_engenharia.pdf", pagesize=letter)
    pdf.setTitle("Relatório de Laudo de Engenharia Civil")
    
    # Adicionar título
    pdf.setFont("Helvetica-Bold", 24)
    pdf.drawString(100, 750, "Relatório de Laudo de Engenharia Civil")
    
    # Adicionar dados
    pdf.setFont("Helvetica-Bold", 18)
    pdf.drawString(100, 700, "Dados Coletados:")
    
    pdf.setFont("Helvetica", 12)
    y = 670
    for key, value in dados.items():
        if key not in ['Categorias', 'Valores']:  # Evitar adicionar listas
            pdf.drawString(100, y, f"{key}: {value}")
            y -= 20

    # Adicionar gráfico
    pdf.setFont("Helvetica-Bold", 18)
    pdf.drawString(100, y, "Gráfico de Distribuição:")
    y -= 20

    adicionar_imagem(pdf, 'grafico.png', 100, y, 400, 200)

    # Salvar o documento
    pdf.save()
    print("Relatório PDF gerado com sucesso!")

# Função para criar um relatório em Word
def criar_relatorio_word(dados):
    if len(dados['Categorias']) != len(dados['Valores']):
        raise ValueError("O número de categorias deve ser igual ao número de valores.")

    # Criar documento Word
    doc = Document()
    doc.add_heading('Relatório de Laudo de Engenharia Civil', level=1)

    # Adicionar dados
    doc.add_heading('Dados Coletados', level=2)
    for key, value in dados.items():
        if key not in ['Categorias', 'Valores']:  # Evitar adicionar listas
            doc.add_paragraph(f"{key}: {value}")

    # Criar e adicionar gráfico
    criar_grafico(dados['Categorias'], dados['Valores'])
    doc.add_heading('Gráfico de Distribuição', level=2)
    doc.add_picture('grafico.png', width=Inches(5.5))  # Ajuste do tamanho da imagem

    # Salvar o documento
    doc.save('relatorio_laudo_engenharia.docx')
    print("Relatório Word gerado com sucesso!")

# Exemplo de dados
dados = {
    'Data da Inspeção': '2024-10-29',
    'Engenheiro Responsável': 'Eng. Natanael Ribeiro',
    'Categorias': ['Estruturas', 'Fundação', 'Acabamentos'],
    'Valores': [100, 70, 90],
    'Observações': 'Tudo dentro dos padrões exigidos.'
}

# Gerar os relatórios
criar_relatorio_pdf(dados)
criar_relatorio_word(dados)
# Out:
# Relatório PDF gerado com sucesso!
# Relatório Word gerado com sucesso!

# %%
import matplotlib.pyplot as plt
from docx import Document
from docx.shared import Inches
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas

# Função para criar um gráfico
def criar_grafico(categorias, valores):
    plt.figure(figsize=(10, 5))
    plt.bar(categorias, valores, color='blue')
    plt.title('Distribuição de Valores por Categoria')
    plt.xlabel('Categorias')
    plt.ylabel('Valores')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig('grafico.png')
    plt.close()

# Função para adicionar uma imagem ao PDF
def adicionar_imagem(pdf, img_path, x, y, width, height):
    pdf.drawImage(img_path, x, y, width, height, preserveAspectRatio=True)

# Função para criar um relatório em PDF
def criar_relatorio_pdf(dados, fotos):
    if len(dados['Categorias']) != len(dados['Valores']):
        raise ValueError("O número de categorias deve ser igual ao número de valores.")

    # Criar gráfico
    criar_grafico(dados['Categorias'], dados['Valores'])

    # Criar PDF
    pdf = canvas.Canvas("relatorio_laudo_engenharia.pdf", pagesize=letter)
    pdf.setTitle("Relatório de Laudo de Engenharia Civil")
    
    # Adicionar título
    pdf.setFont("Helvetica-Bold", 24)
    pdf.drawString(100, 750, "Relatório de Laudo de Engenharia Civil")
    
    # Adicionar dados
    pdf.setFont("Helvetica-Bold", 18)
    pdf.drawString(100, 720, "Dados Coletados:")
    
    pdf.setFont("Helvetica", 12)
    y = 690
    for key, value in dados.items():
        if key not in ['Categorias', 'Valores']:  # Evitar adicionar listas
            pdf.drawString(100, y, f"{key}: {value}")
            y -= 20

    # Adicionar gráfico
    pdf.setFont("Helvetica-Bold", 18)
    pdf.drawString(100, y, "Gráfico de Distribuição:")
    y -= 20

    # Ajustar a posição do gráfico
    adicionar_imagem(pdf, 'grafico.png', 100, y, 400, 200)
    y -= 220  # Espaço abaixo do gráfico

    # Seção de Fotos
    pdf.setFont("Helvetica-Bold", 18)
    pdf.drawString(100, y, "Área de Fotos:")
    y -= 20
    for foto in fotos:
        adicionar_imagem(pdf, foto, 100, y, 200, 150)  # Tamanho ajustado para fotos
        y -= 160  # Espaço para a próxima foto

    # Salvar o documento
    pdf.save()
    print("Relatório PDF gerado com sucesso!")

# Função para criar um relatório em Word
def criar_relatorio_word(dados, fotos):
    if len(dados['Categorias']) != len(dados['Valores']):
        raise ValueError("O número de categorias deve ser igual ao número de valores.")

    # Criar documento Word
    doc = Document()
    doc.add_heading('Relatório de Laudo de Engenharia Civil', level=1)

    # Adicionar dados
    doc.add_heading('Dados Coletados', level=2)
    for key, value in dados.items():
        if key not in ['Categorias', 'Valores']:  # Evitar adicionar listas
            doc.add_paragraph(f"{key}: {value}")

    # Criar e adicionar gráfico
    criar_grafico(dados['Categorias'], dados['Valores'])
    doc.add_heading('Gráfico de Distribuição', level=2)
    doc.add_picture('grafico.png', width=Inches(5.5))

    # Seção de Fotos
    doc.add_heading('Área de Fotos', level=2)
    for foto in fotos:
        doc.add_picture(foto, width=Inches(3.0))  # Ajuste do tamanho da imagem
        doc.add_paragraph()  # Espaço entre as fotos

    # Salvar o documento
    doc.save('relatorio_laudo_engenharia.docx')
    print("Relatório Word gerado com sucesso!")

# Exemplo de dados
dados = {
    'Data da Inspeção': '2024-10-29',
    'Engenheiro Responsável': 'Eng. Natanael Ribeiro',
    'Categorias': ['Estruturas', 'Fundação', 'Acabamentos'],
    'Valores': [100, 70, 90],
    'Observações': 'Tudo dentro dos padrões exigidos.'
}

# Lista de fotos (substitua com os caminhos corretos das suas fotos)
fotos = ['foto1.jpg', 'foto2.jpg', 'foto3.jpg']  # Adicione os nomes dos arquivos de imagem

# Gerar os relatórios
criar_relatorio_pdf(dados, fotos)
criar_relatorio_word(dados, fotos)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\ead\Desktop\creditscoring_tarde\.venv\Lib\site-packages\reportlab\lib\utils.py:523, in open_for_read.<locals>.open_for_read(name, mode)
#     522 try:
# --> 523     return open_for_read_by_name(name,mode)
#     524 except:
#
# File c:\Users\ead\Desktop\creditscoring_tarde\.venv\Lib\site-packages\reportlab\lib\utils.py:463, in open_for_read_by_name(name, mode)
#     462 try:
# --> 463     return open(name,mode)
#     464 except IOError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'foto1.jpg'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File c:\Users\ead\Desktop\creditscoring_tarde\.venv\Lib\site-packages\reportlab\lib\utils.py:530, in open_for_read.<locals>.open_for_read(name, mode)
# ...

# %%
import os
import matplotlib.pyplot as plt
from docx import Document
from docx.shared import Inches
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas

# Função para criar um gráfico
def criar_grafico(categorias, valores):
    plt.figure(figsize=(10, 5))
    plt.bar(categorias, valores, color='blue')
    plt.title('Distribuição de Valores por Categoria')
    plt.xlabel('Categorias')
    plt.ylabel('Valores')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig('grafico.png')
    plt.close()

# Função para adicionar uma imagem ao PDF
def adicionar_imagem(pdf, img_path, x, y, width, height):
    pdf.drawImage(img_path, x, y, width, height, preserveAspectRatio=True)

# Função para criar um relatório em PDF
def criar_relatorio_pdf(dados, fotos, pasta):
    if len(dados['Categorias']) != len(dados['Valores']):
        raise ValueError("O número de categorias deve ser igual ao número de valores.")

    # Criar gráfico
    criar_grafico(dados['Categorias'], dados['Valores'])

    # Criar PDF
    pdf_path = os.path.join(pasta, "relatorio_laudo_engenharia.pdf")
    pdf = canvas.Canvas(pdf_path, pagesize=letter)
    pdf.setTitle("Relatório de Laudo de Engenharia Civil")
    
    # Adicionar título
    pdf.setFont("Helvetica-Bold", 24)
    pdf.drawString(100, 750, "Relatório de Laudo de Engenharia Civil")
    
    # Adicionar dados
    pdf.setFont("Helvetica-Bold", 18)
    pdf.drawString(100, 720, "Dados Coletados:")
    
    pdf.setFont("Helvetica", 12)
    y = 690
    for key, value in dados.items():
        if key not in ['Categorias', 'Valores']:  # Evitar adicionar listas
            pdf.drawString(100, y, f"{key}: {value}")
            y -= 20

    # Adicionar gráfico
    pdf.setFont("Helvetica-Bold", 18)
    pdf.drawString(100, y, "Gráfico de Distribuição:")
    y -= 20

    # Ajustar a posição do gráfico
    adicionar_imagem(pdf, 'grafico.png', 100, y, 400, 200)
    y -= 220  # Espaço abaixo do gráfico

    # Seção de Fotos
    pdf.setFont("Helvetica-Bold", 18)
    pdf.drawString(100, y, "Área de Fotos:")
    y -= 20
    for foto in fotos:
        adicionar_imagem(pdf, foto, 100, y, 200, 150)  # Tamanho ajustado para fotos
        y -= 160  # Espaço para a próxima foto

    # Salvar o documento
    pdf.save()
    print("Relatório PDF gerado com sucesso!")

# Função para criar um relatório em Word
def criar_relatorio_word(dados, fotos, pasta):
    if len(dados['Categorias']) != len(dados['Valores']):
        raise ValueError("O número de categorias deve ser igual ao número de valores.")

    # Criar documento Word
    doc_path = os.path.join(pasta, "relatorio_laudo_engenharia.docx")
    doc = Document()
    doc.add_heading('Relatório de Laudo de Engenharia Civil', level=1)

    # Adicionar dados
    doc.add_heading('Dados Coletados', level=2)
    for key, value in dados.items():
        if key not in ['Categorias', 'Valores']:  # Evitar adicionar listas
            doc.add_paragraph(f"{key}: {value}")

    # Criar e adicionar gráfico
    criar_grafico(dados['Categorias'], dados['Valores'])
    doc.add_heading('Gráfico de Distribuição', level=2)
    doc.add_picture('grafico.png', width=Inches(5.5))

    # Seção de Fotos
    doc.add_heading('Área de Fotos', level=2)
    for foto in fotos:
        doc.add_picture(foto, width=Inches(3.0))  # Ajuste do tamanho da imagem
        doc.add_paragraph()  # Espaço entre as fotos

    # Salvar o documento
    doc.save(doc_path)
    print("Relatório Word gerado com sucesso!")

# Função principal
def main():
    # Exemplo de dados
    dados = {
        'Data da Inspeção': '2024-10-29',
        'Engenheiro Responsável': 'Eng. Natanael Ribeiro',
        'Categorias': ['Estruturas', 'Fundação', 'Acabamentos'],
        'Valores': [100, 70, 90],
        'Observações': 'Tudo dentro dos padrões exigidos.'
    }

    # Lista de fotos (substitua com os caminhos corretos das suas fotos)
    fotos = ['foto1.jpg', 'foto2.jpg', 'foto3.jpg']  # Adicione os nomes dos arquivos de imagem

    # Criar pasta para os relatórios
    pasta = "Relatorios_Engenharia"
    os.makedirs(pasta, exist_ok=True)  # Cria a pasta se não existir

    # Gerar os relatórios
    criar_relatorio_pdf(dados, fotos, pasta)
    criar_relatorio_word(dados, fotos, pasta)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\ead\Desktop\creditscoring_tarde\.venv\Lib\site-packages\reportlab\lib\utils.py:523, in open_for_read.<locals>.open_for_read(name, mode)
#     522 try:
# --> 523     return open_for_read_by_name(name,mode)
#     524 except:
#
# File c:\Users\ead\Desktop\creditscoring_tarde\.venv\Lib\site-packages\reportlab\lib\utils.py:463, in open_for_read_by_name(name, mode)
#     462 try:
# --> 463     return open(name,mode)
#     464 except IOError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'foto1.jpg'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File c:\Users\ead\Desktop\creditscoring_tarde\.venv\Lib\site-packages\reportlab\lib\utils.py:530, in open_for_read.<locals>.open_for_read(name, mode)
# ...

# %%
import os
from datetime import datetime
from docx import Document
import matplotlib.pyplot as plt

# Função para criar um gráfico
def criar_grafico(categorias, valores, nome_arquivo):
    plt.figure(figsize=(10, 5))
    plt.bar(categorias, valores, color='blue')
    plt.title('Distribuição de Valores por Categoria')
    plt.xlabel('Categorias')
    plt.ylabel('Valores')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(nome_arquivo)
    plt.close()

# Função para criar um relatório
def criar_relatorio(dados):
    # Validação dos dados
    if len(dados['Categorias']) != len(dados['Valores']):
        raise ValueError("O número de categorias deve ser igual ao número de valores.")

    # Criar diretório para relatórios, se não existir
    pasta_relatorios = os.path.join(os.path.expanduser("~"), "Documentos", "Relatorios")
    os.makedirs(pasta_relatorios, exist_ok=True)

    # Nomes dinâmicos para os arquivos
    nome_grafico = os.path.join(pasta_relatorios, f'grafico_{datetime.now().strftime("%Y%m%d_%H%M%S")}.png')
    nome_relatorio = os.path.join(pasta_relatorios, f'relatorio_laudo_engenharia_{datetime.now().strftime("%Y%m%d_%H%M%S")}.docx')

    # Criar o documento Word
    doc = Document()
    doc.add_heading('Relatório de Laudo de Engenharia Civil', level=1)

    # Adicionar dados
    doc.add_heading('Dados Coletados', level=2)
    for key, value in dados.items():
        if key not in ['Categorias', 'Valores']:  # Evitar adicionar listas
            doc.add_paragraph(f"{key}: {value}")

    # Criar e adicionar gráfico
    criar_grafico(dados['Categorias'], dados['Valores'], nome_grafico)
    doc.add_heading('Gráfico de Distribuição', level=2)
    doc.add_picture(nome_grafico)

    # Salvar o documento
    doc.save(nome_relatorio)
    print(f"Relatório gerado com sucesso em: {nome_relatorio}")

# Exemplo de dados
dados = {
    'Data da Inspeção': '2024-10-29',
    'Engenheiro Responsável': 'Eng. Natanael Ribeiro',
    'Categorias': ['Estruturas', 'Fundação', 'Acabamentos'],
    'Valores': [100, 70, 90],
    'Observações': 'Tudo dentro dos padrões exigidos.'
}

# Gerar o relatório
criar_relatorio(dados)
# Out:
# Relatório gerado com sucesso em: C:\Users\ead\Documentos\Relatorios\relatorio_laudo_engenharia_20241029_175135.docx

# %%
import os
from datetime import datetime
from docx import Document
import matplotlib.pyplot as plt

# Função para criar um gráfico
def criar_grafico(categorias, valores, nome_arquivo):
    plt.figure(figsize=(10, 5))
    plt.bar(categorias, valores, color='blue')
    plt.title('Distribuição de Valores por Categoria')
    plt.xlabel('Categorias')
    plt.ylabel('Valores')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(nome_arquivo)
    plt.close()

# Função para criar um relatório
def criar_relatorio(dados):
    # Validação dos dados
    if len(dados['Categorias']) != len(dados['Valores']):
        raise ValueError("O número de categorias deve ser igual ao número de valores.")

    # Criar diretório para relatórios, se não existir
    pasta_relatorios = os.path.join(os.path.expanduser("~"), "Documentos", "Relatorios")
    os.makedirs(pasta_relatorios, exist_ok=True)
    print(f"Pasta para relatórios criada em: {pasta_relatorios}")

    # Nomes dinâmicos para os arquivos
    nome_grafico = os.path.join(pasta_relatorios, f'grafico_{datetime.now().strftime("%Y%m%d_%H%M%S")}.png')
    nome_relatorio = os.path.join(pasta_relatorios, f'relatorio_laudo_engenharia_{datetime.now().strftime("%Y%m%d_%H%M%S")}.docx')

    # Criar o documento Word
    doc = Document()
    doc.add_heading('Relatório de Laudo de Engenharia Civil', level=1)

    # Adicionar dados
    doc.add_heading('Dados Coletados', level=2)
    for key, value in dados.items():
        if key not in ['Categorias', 'Valores']:  # Evitar adicionar listas
            doc.add_paragraph(f"{key}: {value}")

    # Criar e adicionar gráfico
    criar_grafico(dados['Categorias'], dados['Valores'], nome_grafico)
    doc.add_heading('Gráfico de Distribuição', level=2)
    doc.add_picture(nome_grafico)

    # Salvar o documento
    doc.save(nome_relatorio)
    print(f"Relatório gerado com sucesso em: {nome_relatorio}")

# Exemplo de dados
dados = {
    'Data da Inspeção': '2024-10-29',
    'Engenheiro Responsável': 'Eng. Natanael Ribeiro',
    'Categorias': ['Estruturas', 'Fundação', 'Acabamentos'],
    'Valores': [100, 70, 90],
    'Observações': 'Tudo dentro dos padrões exigidos.'
}

# Gerar o relatório
criar_relatorio(dados)
# Out:
# Pasta para relatórios criada em: C:\Users\ead\Documentos\Relatorios
# Relatório gerado com sucesso em: C:\Users\ead\Documentos\Relatorios\relatorio_laudo_engenharia_20241029_175917.docx
